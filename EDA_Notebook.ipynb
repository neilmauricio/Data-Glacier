# %% [markdown]
# <a href="https://colab.research.google.com/github/neilmauricio/Data-Glacier/blob/main/EDA_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Descriptive Analysis**
#
# **Cab_Data:**
#
# Transaction ID, Date of Travel, Company, City  --> Categorical
#
# KM Traveled, Price Charged, Cost of Trip --> Numerical
#
#
# **City:**
#
# City --> Categorical
#
# Population, Users --> Numerical
#
# **Customer_id:**
#
# Customer ID, Gender --> Categorical
#
# Age, Income (USD/Month) --> Numerical
#
# **transaction_id:**
#
# Transaction ID, Customer ID --> Categorical
#
# Payment_Mode --> Numerical

# %% [markdown]
# **Hypothesis 1**:
# 1. Is the 'Cost of Trip' of Yellow Cab greater than Pink Cab?
# ![Cost of Trip.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Hypothesis 2**:
# 2. Does NY city have the greatest 'Cost of Trip' and mayor population?
# ![NY City.jpg](data:image/jpeg;base64,...)
